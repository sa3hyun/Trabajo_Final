# %%
import pandas as pd

# %%
df_1= pd.read_csv("pib.csv")

# %%
df_1['Country Name']
# Out:
# 0                                                  Aruba
# 1                                                    NaN
# 2                                             Afganistán
# 3                                                    NaN
# 4                                                 Angola
# 5                                                Albania
# 6                                                Andorra
# 7                                         El mundo árabe
# 8                                 Emiratos Árabes Unidos
# 9                                              Argentina
# 10                                               Armenia
# 11                                       Samoa Americana
# 12                                     Antigua y Barbuda
# 13                                             Australia
# 14                                               Austria
# 15                                            Azerbaiyán
# ...

# %%
pd.set_option('display.max_rows', None)
print(df_1['Country Name'])
# Out:
# 0                                                  Aruba
# 1                                                    NaN
# 2                                             Afganistán
# 3                                                    NaN
# 4                                                 Angola
# 5                                                Albania
# 6                                                Andorra
# 7                                         El mundo árabe
# 8                                 Emiratos Árabes Unidos
# 9                                              Argentina
# 10                                               Armenia
# 11                                       Samoa Americana
# 12                                     Antigua y Barbuda
# 13                                             Australia
# 14                                               Austria
# 15                                            Azerbaiyán
# ...

# %%
paises_america = ['Antigua y Barbuda', 'Argentina', 'Bahamas', 'Barbados', 'Belice', 'Bolivia', 'Brasil', 'Canadá', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominica', 'Ecuador', 'El Salvador', 'Estados Unidos', 'Granada', 'Guatemala', 'Guyana', 'Haití', 'Honduras', 'Jamaica', 'México', 'Nicaragua', 'Panamá', 'Paraguay', 'Perú', 'República Dominicana', 'San Vicente y las Granadinas', 'Santa Lucía', 'Suriname', 'Trinidad y Tobago', 'Uruguay', 'Venezuela']

# %%
df = df_1[df_1['Country Name'].isin(paises_america)]

# %%
df['Country Name']
# Out:
# 9                         Argentina
# 12                Antigua y Barbuda
# 23                          Bahamas
# 26                           Belice
# 28                          Bolivia
# 29                           Brasil
# 30                         Barbados
# 35                           Canadá
# 39                            Chile
# 45                         Colombia
# 48                       Costa Rica
# 50                             Cuba
# 57                         Dominica
# 59             República Dominicana
# 66                          Ecuador
# 89                          Granada
# 91                        Guatemala
# 93                           Guyana
# 96                         Honduras
# 99                            Haití
# 116                         Jamaica
# 132                     Santa Lucía
# 153                          México
# 174                       Nicaragua
# 184                          Panamá
# 185                            Perú
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 9 to 253
# Data columns (total 68 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    34 non-null     int64
#  1   Country Name  34 non-null     object
#  2   Country Code  34 non-null     object
#  3   1961          27 non-null     float64
#  4   1962          27 non-null     float64
#  5   1963          27 non-null     float64
#  6   1964          27 non-null     float64
#  7   1965          27 non-null     float64
#  8   1966          28 non-null     float64
#  9   1967          29 non-null     float64
#  10  1968          29 non-null     float64
#  11  1969          29 non-null     float64
#  12  1970          29 non-null     float64
#  13  1971          30 non-null     float64
#  14  1972          30 non-null     float64
#  15  1973          30 non-null     float64
#  16  1974          30 non-null     float64
#  17  1975          30 non-null     float64
# ...

# %%
df.head()
# Out:
#     Unnamed: 0       Country Name Country Code       1961       1962  \
# 9            9          Argentina          ARG   5.427843  -0.852022
# 12          12  Antigua y Barbuda          ATG        NaN        NaN
# 23          23            Bahamas          BHS  10.667097  10.451972
# 26          26             Belice          BLZ   4.892277   4.892652
# 28          28            Bolivia          BOL   2.089296   5.578918
#
#          1963       1964       1965      1966      1967  ...      2016  \
# 9   -5.308197  10.130298  10.569433 -0.659726  3.191997  ... -2.080328
# 12        NaN        NaN        NaN       NaN       NaN  ...  4.120368
# 23  10.524055  10.501567  10.425596  9.071929  9.598114  ... -1.156508
# 26   4.956434   4.999880   4.930541  4.770845  4.913123  ... -0.018741
# 28   6.797626   3.956597   4.913442  7.170590  6.317220  ...  4.263921
#
#         2017      2018      2019       2020       2021       2022      2023  \
# ...

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
# Out:
# /tmp/ipykernel_1144/4136117298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022', '2023', '2024', '2025'],
#       dtype='object')

# %%
nulos = df.isnull().sum().sort_values(ascending=False)
nulos[nulos > 0]
# Out:
# 1961    7
# 1963    7
# 1962    7
# 1964    7
# 1965    7
# 1966    6
# 1967    5
# 1970    5
# 1969    5
# 1968    5
# 1971    4
# 1974    4
# 1975    4
# 1972    4
# 1973    4
# 1976    4
# 1977    4
# 2025    2
# dtype: int64

# %%
df['Country Name'].mode()
# Out:
# 0                Antigua y Barbuda
# 1                        Argentina
# 2                          Bahamas
# 3                         Barbados
# 4                           Belice
# 5                          Bolivia
# 6                           Brasil
# 7                           Canadá
# 8                            Chile
# 9                         Colombia
# 10                      Costa Rica
# 11                            Cuba
# 12                        Dominica
# 13                         Ecuador
# 14                     El Salvador
# 15                  Estados Unidos
# 16                         Granada
# 17                       Guatemala
# 18                          Guyana
# 19                           Haití
# 20                        Honduras
# 21                         Jamaica
# 22                          México
# 23                       Nicaragua
# 24                          Panamá
# 25                        Paraguay
# 26                            Perú
# ...

# %%
df[['1961', '1962', '1963', '1964', '1965',
       '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022', '2023', '2024', '2025']].median()
# Out:
# 1961    4.892277
# 1962    5.411890
# 1963    4.710291
# 1964    5.800000
# 1965    4.930541
# 1966    5.374420
# 1967    4.134864
# 1968    5.215142
# 1969    4.736909
# 1970    4.941887
# 1971    4.304692
# 1972    5.136571
# 1973    5.504995
# 1974    5.434903
# 1975    2.561628
# 1976    5.298744
# 1977    5.626284
# 1978    5.621016
# 1979    4.523075
# 1980    4.230209
# 1981    3.027257
# 1982   -0.095115
# 1983    1.223603
# 1984    3.083642
# 1985    1.959608
# 1986    4.057585
# 1987    3.492315
# 1988    3.605461
# 1989    3.507048
# 1990    3.327813
# 1991    2.242457
# 1992    3.545555
# 1993    4.088931
# 1994    4.031382
# 1995    3.878641
# 1996    3.874624
# 1997    4.593616
# 1998    3.892953
# 1999    2.710279
# 2000    3.705470
# 2001    1.680849
# 2002    2.494773
# 2003    3.729529
# 2004    4.602632
# 2005    4.129532
# 2006    5.240504
# 2007    5.263084
# 2008    3.413727
# 2009   -1.126894
# 2010    3.527183
# 2011    4.048143
# 2012    3.194022
# ...

# %%
df['Country Name'] = df['Country Name'].fillna(df['Country Name'].mode()[0])
# Out:
# /tmp/ipykernel_1144/991798221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country Name'] = df['Country Name'].fillna(df['Country Name'].mode()[0])

# %%
df[['1961', '1962', '1963', '1964', '1965',
       '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022', '2023', '2024', '2025']] = df[['1961', '1962', '1963', '1964', '1965',
       '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022', '2023', '2024', '2025']].fillna(df[['1961', '1962', '1963', '1964', '1965',
       '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022', '2023', '2024', '2025']].median())
# Out:
# /tmp/ipykernel_1144/247990339.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['1961', '1962', '1963', '1964', '1965',

# %%
nulos = df.isnull().sum().sort_values(ascending=False)
nulos[nulos > 0]
# Out:
# Series([], dtype: int64)
